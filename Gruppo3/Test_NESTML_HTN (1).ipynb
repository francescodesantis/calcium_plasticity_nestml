# %%
#%matplotlib inline
#import matplotlib as mpl
#mpl.rcParams['axes.formatter.useoffset'] = False
#import matplotlib.pyplot as plt
#import nest
#import numpy as np
#import os
#import re

#from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils

# %matplotlib inline

from typing import List, Optional

import matplotlib as mpl

mpl.rcParams['axes.formatter.useoffset'] = False
mpl.rcParams['axes.grid'] = True
mpl.rcParams['grid.color'] = 'k'
mpl.rcParams['grid.linestyle'] = ':'
mpl.rcParams['grid.linewidth'] = 0.5
mpl.rcParams['figure.dpi'] = 120
mpl.rcParams['figure.figsize'] = [8., 3.]

import matplotlib.pyplot as plt
import numpy as np
import os
import pytest
import random
import re

import nest

from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
from matplotlib import rcParams

text_color = 'black' 
rcParams['text.color'] = text_color 
rcParams['axes.labelcolor'] = text_color 
rcParams['xtick.color'] = text_color 
rcParams['ytick.color'] = text_color 
plt.rc('font', size=12)          # controls default text sizes 
plt.rc('axes', titlesize=20)     # fontsize of the axes title 
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels 
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels 
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels 
plt.rc('legend', fontsize=12)    # legend fontsize 
plt.rc('figure', titlesize=26)  # fontsize of the figure title

# %%
module_name, neuron_model_name, synapse_model_name = \
    NESTCodeGeneratorUtils.generate_code_for(nestml_neuron_model= "hill_tononi_.nestml",
                                             nestml_synapse_model= "stdpClear_synapse_.nestml",
                                             module_name= "nestml_module",
                                             post_ports = ["post_spikes",["rho_GB_post","rho_GB"]],
                                             target_path = "HT21_target",
                                             logging_level="DEBUG")
# Out:
# WARNING:root:PyGSL is not available. The stiffness test will be skipped.
# WARNING:root:Error when importing: No module named 'pygsl'
# [1,GLOBAL, INFO]: List of files that will be processed:
# [2,GLOBAL, INFO]: /opt/app-root/src/PW4/hill_tononi.nestml
# [3,GLOBAL, INFO]: /opt/app-root/src/PW4/stdpClear.nestml
# [4,GLOBAL, INFO]: Target platform code will be generated in directory: '/opt/app-root/src/PW4/HT21_target'
# [5,GLOBAL, INFO]: Target platform code will be installed in directory: '/tmp/nestml_target_wnel47bx'
#
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# [6,GLOBAL, INFO]: The NEST Simulator version was automatically detected as: v3.7.0
# ...

# %% [markdown]
# # Now we can use the new module

# %%
#TEST FUNZIONANTE PER HILL-TONONI CON STDP SYNAPSE

#os.environ['LD_LIBRARY_PATH'] = '/tmp/nestml_target:' + os.environ.get('LD_LIBRARY_PATH', '')
nest.ResetKernel()
nest.Install("HT21_target/nestml_module")
nest.set_verbosity("M_ERROR")


delta_t = 30  # ms
duration = 150000 # ms
frequency = 1 # HzNESTCodeGeneratorUtils.generate_code_for()

#nest.SetDefaults("hill_tononi_nestml__with_stdp_nestml", {"I_e": 40.0})

#pre_neuron = nest.Create("hill_tononi_nestml__with_stdp_nestml", 1, {"I_e": 350.0})
#post_neuron = nest.Create("hill_tononi_nestml__with_stdp_nestml", 1, {"I_e": 350.0})

pre_neuron = nest.Create("hill_tononi_nestml__with_stdpClear_nestml", 1)
post_neuron = nest.Create("hill_tononi_nestml__with_stdpClear_nestml", 1)

wr = nest.Create("weight_recorder")
#nest.SetDefaults("static_synapse", {"weight_recorder": wr[0]})
nest.SetDefaults("stdpClear_nestml__with_hill_tononi_nestml", {"weight_recorder": wr[0]})
#nest.SetDefaults("hill_tononi_nestml__with_stdp_nestml", {"NaP_g_peak": 0.0, "KNa_g_peak": 0.0, "T_g_peak": 0.0, "h_g_peak": 0.0})
#nest.SetStatus(pre_neuron, {"I_NaP_min": 0.1})
#nest.SetStatus(post_neuron, {"I_NaP_min": 0.1})
#nest.SetStatus(pre_neuron, {"NaP_g_peak": 5.0, "T_g_peak": 5.0})
#nest.SetStatus(post_neuron, {"NaP_g_peak": 5.0, "T_g_peak": 5.0})

#nest.SetStatus(post_neuron, {"potassium_refr_t": 0.0})
interval = 1000.0 / frequency
spike_times = np.arange(interval, duration, interval)
spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

#spike_generator = nest.Create("spike_generator", {"spike_times": np.array([20.0])})

#,300.0,400.0,500.0,600.0,700.0,800.0,900.0


receptor_types = nest.GetStatus(post_neuron, "receptor_types")[0]
#print(receptor_types)

#nest.Connect(pre_neuron, post_neuron, "one_to_one", "static_synapse")
#nest.Connect(pre_neuron, post_neuron, "one_to_one", "stdp_nestml__with_hill_tononi_nestml")
#25.0, "NMDA": 20.0, "GABA_A": 10.0, "GABA_B": 1.0

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "stdpClear_nestml__with_hill_tononi_nestml",
                                                              "receptor_type" : receptor_types["AMPA"],
                                                               "weight": 3.125})

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "static_synapse",
                                                              "receptor_type" : receptor_types["GABA_A"],
                                                               "weight": 2.5})

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "static_synapse",
                                                              "receptor_type" : receptor_types["GABA_B"],
                                                               "weight": 2.5})

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "static_synapse",
                                                              "receptor_type" : receptor_types["NMDA"],
                                                               "weight": 2.5})
             
if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t

else:
    delta_pre = -1 * delta_t
    delta_post = 0.0
             
###spike generator per il neurone pre

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight":25.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["AMPA"]})

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 10.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["GABA_A"]})

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 1.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["GABA_B"]})

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 20.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["NMDA"]})

###spike generator per il neurone post

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 25.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["AMPA"]})

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                         "weight": 10.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["GABA_A"]})

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 1.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["GABA_B"]})

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 20.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["NMDA"]})
#questa roba funziona!


sd = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd, "one_to_one")
nest.Connect(post_neuron, sd, "one_to_one")

vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
nest.Connect(vm_pre, pre_neuron, "one_to_one")
nest.Connect(vm_post, post_neuron, "one_to_one")

# Creazione di registratori per correnti specifiche
integrated_conc_Ca_rec = nest.Create("multimeter", {"record_from": ["integrated_conc_Ca"]})
Theta_rec_pre = nest.Create("multimeter", {"record_from": ["Theta"]})
Theta_rec_post = nest.Create("multimeter", {"record_from": ["Theta"]})
Refr_rec_pre = nest.Create("multimeter", {"record_from": ["potassium_refr_t"]})
Refr_rec_post = nest.Create("multimeter", {"record_from": ["potassium_refr_t"]})

nest.Connect(integrated_conc_Ca_rec, post_neuron)
nest.Connect(Theta_rec_post, post_neuron)
nest.Connect(Refr_rec_post, post_neuron)

nest.Connect(Theta_rec_pre, pre_neuron)
nest.Connect(Refr_rec_pre, pre_neuron)

nest.Simulate(duration)

spikes = sd.get(['events'][0]) 

#print(sd.events) #printa gli spike


# Estrazione dei dati registrati dai multimetri
integrated_conc_Ca_events = nest.GetStatus(integrated_conc_Ca_rec, "events")[0]
# Estrazione dei tempi e dei valori delle correnti
times_integrated_conc_Ca = integrated_conc_Ca_events["times"]
values_integrated_conc_Ca = integrated_conc_Ca_events["integrated_conc_Ca"]

# Eventi registrati per il pre-sinaptico
Refr_events_pre = nest.GetStatus(Refr_rec_pre, "events")[0]
Theta_events_pre = nest.GetStatus(Theta_rec_pre, "events")[0]

# Eventi registrati per il post-sinaptico
Refr_events_post = nest.GetStatus(Refr_rec_post, "events")[0]
Theta_events_post = nest.GetStatus(Theta_rec_post, "events")[0]

# Estrazione dei dati per il pre-sinaptico
times_Refr_pre = Refr_events_pre["times"]
values_Refr_pre = Refr_events_pre["potassium_refr_t"]
times_Theta_pre = Theta_events_pre["times"]
values_Theta_pre = Theta_events_pre["Theta"]

# Estrazione dei dati per il post-sinaptico
times_Refr_post = Refr_events_post["times"]
values_Refr_post = Refr_events_post["potassium_refr_t"]
times_Theta_post = Theta_events_post["times"]
values_Theta_post = Theta_events_post["Theta"]



fig, ax = plt.subplots(6, figsize = (18,20))

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
#ax[0].plot(times_Theta_pre, values_Theta_pre, color="green", label="Theta pre")
#ax[0].plot(times_Theta_post, values_Theta_post, color="purple", label="Theta post")
ax[0].set_title("Post-synaptic neuron Potential")
ax[0].set_ylabel("Vm [mV]")
#ax[0].set_xlim([1800,3500])
ax[0].set_xlim([900,1300])
ax[0].legend()

ax[1].set_title("Rasterplot")
ax[1].plot( spikes['times'][np.where(spikes['senders']==1)], spikes['senders'][np.where(spikes['senders']==1)], '.', markersize = 40, alpha = 0.5, color = "b", label = "Pre-synaptic spikes")
ax[1].plot( spikes['times'][np.where(spikes['senders']==2)], spikes['senders'][np.where(spikes['senders']==2)]-1, '.', markersize = 40, alpha = 0.5,color = "orange", label = "Post-synaptic spikes")
ax[1].legend()
ax[1].set_ylabel("Neurons")
ax[1].set_yticklabels("")
#ax[1].set_xlim([0,3500])
ax[1].set_xlim([0,10000])


#print(wr.events["times"], wr.events["weights"])
ax[2].plot(wr.events["times"], wr.events["weights"], color = 'r')
ax[2].set_title("STDP")
ax[2].set_ylabel("Weight [nS]")
ax[2].set_xlabel("Time [ms]")
#ax[2].set_xlim([0,3500])
ax[2].set_xlim([0,100000])

# Plot della concentration_Ca_int
ax[3].plot(times_integrated_conc_Ca, values_integrated_conc_Ca, color="b", label="integrated_conc_Ca")
ax[3].set_ylabel("integrated_conc_Ca mmol/dm**3")
ax[3].set_title("integrated_conc_Ca Registrata")
ax[3].legend()
ax[3].grid(True)
ax[3].set_xlim([0,10000])


# Plot della threshold del neurone
#ax[3].plot(times_Theta_post, values_Theta_post, color="orange", label="potassium_refr_t post")
#ax[3].set_ylabel("Theta post [mV]")
#ax[3].set_title("Threshold post Registrata")
#ax[3].legend()
#ax[3].grid(True)
#ax[3].set_xlim([0,10000])
#fig.tight_layout()



# Plot 
ax[4].plot(times_Refr_post, values_Refr_post, color="b", label="Refrattarietà post")
ax[4].set_ylabel("potassium_refr_t post")
ax[4].set_title("Refrattarietà post Registrata")
ax[4].legend()
ax[4].grid(True)
ax[4].set_xlim([0,10000])

# Plot 
ax[5].plot(times_Refr_pre, values_Refr_pre, color="b", label="Refrattarietà pre")
ax[5].set_ylabel("potassium_refr_t pre")
ax[5].set_title("Refrattarietà pre Registrata")
ax[5].legend()
ax[5].grid(True)
ax[5].set_xlim([0,10000])

fig.tight_layout()
# Out:
# = 126002 msINFO Presinaptic spike: valore di Use = 20.9083 al tempo t = 126032 msINFO Postsinaptic spike: valore di Use = 20.9771 al tempo t = 127002 msINFO Presinaptic spike: valore di Use = 20.9771 al tempo t = 127032 msINFO Postsinaptic spike: valore di Use = 21.0451 al tempo t = 128002 msINFO Presinaptic spike: valore di Use = 21.0451 al tempo t = 128032 msINFO Postsinaptic spike: valore di Use = 21.1123 al tempo t = 129002 msINFO Presinaptic spike: valore di Use = 21.1123 al tempo t = 129032 msINFO Postsinaptic spike: valore di Use = 21.1786 al tempo t = 130002 msINFO Presinaptic spike: valore di Use = 21.1786 al tempo t = 130032 msINFO Postsinaptic spike: valore di Use = 21.2442 al tempo t = 131002 msINFO Presinaptic spike: valore di Use = 21.2442 al tempo t = 131032 msINFO Postsinaptic spike: valore di Use = 21.309 al tempo t = 132002 msINFO Presinaptic spike: valore di Use = 21.309 al tempo t = 132032 msINFO Postsinaptic spike: valore di Use = 21.373 al tempo t = 133002 msINF
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (18,7), sharey = True)

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[0].set_title("First Spike")
ax[0].set_ylabel("Vm [mV]")
ax[0].set_xlim([900,1100])
ax[0].set_xlabel("Time [ms]")
ax[0].legend()

ax[1].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[1].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[1].set_title("Last Spike")
ax[1].set_ylabel("Vm [mV]")
ax[1].set_xlim([69000, 69200])
ax[1].set_ylim([-90, -80])
ax[1].set_xlabel("Time [ms]")
ax[1].legend()

# %%
params = nest.GetDefaults("hill_tononi_nestml__with_stdpClear_nestml")
print(params)
#GetDefaults
# Out:
# {'alpha': 0.6, 'available': (0,), 'beta_Ca': 0.001, 'Ca': 0.0, 'capacity': (2,), 'E_K': -90.0, 'E_Na': 30.0, 'element_type': 'neuron', 'elementsize': 1400, 'frozen': False, 'g_KL': 1.0, 'g_NaL': 0.2, 'global_id': 0, 'gsl_error_tol': 0.001, 'I_e': 0.0, 'instantiations': (2,), 'local': True, 'model': 'hill_tononi_nestml__with_stdpClear_nestml', 'model_id': 100, 'node_uses_wfr': False, 'receptor_types': {'AMPA': 1, 'GABA_A': 3, 'GABA_B': 4, 'NMDA': 2}, 'recordables': ('I_h', 'I_KNa', 'I_NaP', 'I_T', 'V_m', 'potassium_refr_t', 'rho_GB', 'Theta', 'IKNa_D', 'IT_m', 'IT_h', 'Ih_m', 'concentration_Ca_int', 'integrated_conc_Ca', 'I_VDCC_h', 'I_VDCC_m', 'damiano', 'AMPA_g_peak', 'g_GABAA__X__GABA_A', 'g_GABAA__DOLLAR__X__GABA_A', 'g_NMDA__X__NMDA', 'g_NMDA__DOLLAR__X__NMDA', 'g_GABAB__X__GABA_B', 'g_GABAB__DOLLAR__X__GABA_B', 'g_AMPA__X__AMPA', 'g_AMPA__DOLLAR__X__AMPA', 'I_NMDA_Ca', 'I_VDCC', 'AMPA_g_plasticity', 'post_trace__for_stdpClear_nestml', 'dep_GB__for_stdpClear_nestml', 'pot_GB__for
# ...

# %%
###PYTHON TEST PER HILL-TONONI - (non ci sono risultati rilevanti)

# %%
import sys
import math
import numpy as np
import pandas as pd
import scipy.optimize as so
import scipy.integrate as si
import matplotlib.pyplot as plt
import nest

# %matplotlib inline
plt.rcParams["figure.figsize"] = (12, 3)

# %%
nest.ResetKernel()
nest.Install("HT_target/nestml_module")
nest.set_verbosity("M_ALL")


nrn = nest.Create("hill_tononi_nestml__with_stdp_nestml")
ppg = nest.Create(
    "pulsepacket_generator", n=4, params={"pulse_times": [200.0, 700.0], "activity": 10, "sdev": 1.0}
)
#, 2700.0, 3700.0
#700
pr = nest.Create("parrot_neuron", n=4)
mm = nest.Create(
    "multimeter",
    params={
        "interval": 10.0,
        "record_from": ["V_m", "Theta", "I_NaP", "I_KNa", "I_T", "I_h"],
    },
)
sd = nest.Create("spike_recorder")

#"g_AMPA__X__AMPA", "g_NMDA__X__NMDA", "g_GABAA__X__GABA_A", "g_GABAB__X__GABA_B",

weights = {"AMPA": 25.0, "NMDA": 20.0, "GABA_A": 10.0, "GABA_B": 1.0}
receptors = nest.GetDefaults("hill_tononi_nestml__with_stdp_nestml")["receptor_types"]

nest.Connect(ppg, pr, "one_to_one")
for p, (rec_name, rec_wgt) in zip(pr, weights.items()):
    nest.Connect(
        p, nrn, syn_spec={"synapse_model": "stdp_nestml__with_hill_tononi_nestml", "receptor_type": receptors[rec_name], "weight": rec_wgt}
    )
nest.Connect(mm, nrn)
nest.Connect(ppg, sd)
nest.Connect(nrn, sd)


nest.Simulate(1000)

# %%
import matplotlib.pyplot as plt
data = nest.GetStatus(mm)[0]["events"]
t = data["times"]


def texify_name(name):
    return r"${}_{{\mathrm{{{}}}}}$".format(*name.split("_"))

spikes = sd.get(['events'][0]) 

fig, ax = plt.subplots(1, figsize = (10,5))

ax.set_title("Rasterplot")
ax.plot( spikes['times'][np.where(spikes['senders']==1)], spikes['senders'][np.where(spikes['senders']==1)], '.', markersize = 40, alpha = 0.5, color = "b", label = "Pre-synaptic spikes")
ax.plot( spikes['times'][np.where(spikes['senders']==2)], spikes['senders'][np.where(spikes['senders']==2)]-1, '.', markersize = 40, alpha = 0.5,color = "orange", label = "Post-synaptic spikes")
ax.legend()
ax.set_ylabel("Neurons")
ax.set_yticklabels("")
#ax[0].set_xlim([0,3500])
ax.set_xlim([-100,1100])


fig = plt.figure(figsize=(12, 6))

Vax = fig.add_subplot(311)
Vax.plot(t, data["V_m"], "k", lw=1, label=r"$V_m$")
Vax.plot(t, data["Theta"], "r", alpha=0.5, lw=1, label=r"$\Theta$")
Vax.set_ylabel("Potential [mV]")
Vax.legend(fontsize="small")
Vax.set_title("ht_neuron driven by sinousiodal Poisson processes")

Iax = fig.add_subplot(312)
for iname, color in (("I_h", "blue"), ("I_KNa", "green"), ("I_NaP", "red"), ("I_T", "cyan")):
    Iax.plot(t, data[iname], color=color, lw=1, label=texify_name(iname))
# Iax.set_ylim(-60, 60)
Iax.legend(fontsize="small")
Iax.set_ylabel("Current [mV]")

Gax = fig.add_subplot(313)
for gname, sgn, color in (
    ("g_AMPA", 1, "green"),
    ("g_GABA_A", -1, "red"),
    ("g_GABA_B", -1, "cyan"),
    ("g_NMDA", 1, "magenta"),
):
    Gax.plot(t, sgn * data[gname], lw=1, label=texify_name(gname), color=color)
# Gax.set_ylim(-150, 150)
Gax.legend(fontsize="small")
Gax.set_ylabel("Conductance")
Gax.set_xlabel("Time [ms]");

# %%
def Vpass(t, V0, gNaL, ENa, gKL, EK, taum, I=0):
    tau_eff = taum / (gNaL + gKL)
    Vinf = (gNaL * ENa + gKL * EK + I) / (gNaL + gKL)
    return V0 * np.exp(-t / tau_eff) + Vinf * (1 - np.exp(-t / tau_eff))


def theta(t, th0, theq, tauth):
    return th0 * np.exp(-t / tauth) + theq * (1 - np.exp(-t / tauth))

# %%
nest.ResetKernel()
nest.Install("HT_target/nestml_module")
nest.set_verbosity("M_ERROR")

nest.SetDefaults(
    "hill_tononi_nestml__with_stdp_nestml", {"NaP_g_peak": 0.0, "KNa_g_peak": 0.0, "T_g_peak": 0.0, "h_g_peak": 0.0, "Tau_theta": 10.0}
)
hp = nest.GetDefaults("hill_tononi_nestml__with_stdp_nestml")

V_0 = [-100.0, -70.0, -55.0]
th_0 = [-65.0, -51.0, -10.0]
T_sim = 20.0

nrns = nest.Create("hill_tononi_nestml__with_stdp_nestml", n=len(V_0), params={"V_m": V_0, "Theta": th_0})

nest.Simulate(T_sim)
V_th_sim = nrns.get(["V_m", "Theta"])

for V0, th0, Vsim, thsim in zip(V_0, th_0, V_th_sim["V_m"], V_th_sim["Theta"]):
    Vex = Vpass(T_sim, V0, hp["g_NaL"], hp["E_Na"], hp["g_KL"], hp["E_K"], hp["Tau_m"])
    thex = theta(T_sim, th0, hp["Theta_eq"], hp["Tau_theta"])
    print("Vex  = {:.3f}, Vsim  = {:.3f}, Vex-Vsim   = {:.3e}".format(Vex, Vsim, Vex - Vsim))
    print("thex = {:.3f}, thsim = {:.3f}, thex-thsim = {:.3e}".format(thex, thsim, thex - thsim))

# %%
nest.ResetKernel()
nest.SetDefaults(
    "ht_neuron", {"g_peak_NaP": 0.0, "g_peak_KNa": 0.0, "g_peak_T": 0.0, "g_peak_h": 0.0, "tau_theta": 10.0}
)
hp = nest.GetDefaults("ht_neuron")

V_0 = [-100.0, -70.0, -55.0]
th_0 = [-65.0, -51.0, -10.0]
T_sim = 20.0

nrns = nest.Create("ht_neuron", n=len(V_0), params={"V_m": V_0, "theta": th_0})

nest.Simulate(T_sim)
V_th_sim = nrns.get(["V_m", "theta"])

for V0, th0, Vsim, thsim in zip(V_0, th_0, V_th_sim["V_m"], V_th_sim["theta"]):
    Vex = Vpass(T_sim, V0, hp["g_NaL"], hp["E_Na"], hp["g_KL"], hp["E_K"], hp["tau_m"])
    thex = theta(T_sim, th0, hp["theta_eq"], hp["tau_theta"])
    print("Vex  = {:.3f}, Vsim  = {:.3f}, Vex-Vsim   = {:.3e}".format(Vex, Vsim, Vex - Vsim))
    print("thex = {:.3f}, thsim = {:.3f}, thex-thsim = {:.3e}".format(thex, thsim, thex - thsim))

# %%
nest.ResetKernel()
nest.Install("HT_target/nestml_module")
nest.set_verbosity("M_ERROR")

class Channel:
    """
    Base class for channel models in Python.
    """

    def tau_m(self, V):
        raise NotImplementedError()

    def tau_h(self, V):
        raise NotImplementedError()

    def m_inf(self, V):
        raise NotImplementedError()

    def h_inf(self, V):
        raise NotImplementedError()

    def D_inf(self, V):
        raise NotImplementedError()

    def dh(self, h, t, V):
        return (self.h_inf(V) - h) / self.tau_h(V)

    def dm(self, m, t, V):
        return (self.m_inf(V) - m) / self.tau_m(V)

def voltage_clamp(channel, DT_V_seq, nest_dt=0.1):
    "Run voltage clamp with voltage V through intervals DT."

    # NEST part
    nest_g_0 = {"h_g_peak": 0.0, "T_g_peak": 0.0, "NaP_g_peak": 0.0, "KNa_g_peak": 0.0}
    nest_g_0[channel.nest_g] = 1.0

    nest.ResetKernel()
    nest.Install("HT_target/nestml_module")
    nest.set_verbosity("M_ERROR")
    nest.resolution = nest_dt
    nrn = nest.Create("hill_tononi_nestml__with_stdp_nestml", params=nest_g_0)
    mm = nest.Create("multimeter", params={"record_from": ["V_m", "Theta", channel.nest_I], "interval": nest_dt})
    nest.Connect(mm, nrn)

    # ensure we start from equilibrated state
    nrn.set(V_m=DT_V_seq[0][1], equilibrate=True, voltage_clamp=True)
    for DT, V in DT_V_seq:
        nrn.set(V_m=V, voltage_clamp=True)
        nest.Simulate(DT)
    t_end = nest.biological_time

    # simulate a little more so we get all data up to t_end to multimeter
    nest.Simulate(2 * nest.min_delay)

    tmp = pd.DataFrame(mm.events)
    nest_res = tmp[tmp.times <= t_end]

    # Control part
    t_old = 0.0
    try:
        m_old = channel.m_inf(DT_V_seq[0][1])
    except NotImplementedError:
        m_old = None
    try:
        h_old = channel.h_inf(DT_V_seq[0][1])
    except NotImplementedError:
        h_old = None
    try:
        D_old = channel.D_inf(DT_V_seq[0][1])
    except NotImplementedError:
        D_old = None

    t_all, I_all = [], []
    if D_old is not None:
        D_all = []

    for DT, V in DT_V_seq:
        t_loc = np.arange(0.0, DT + 0.1 * nest_dt, nest_dt)
        I_loc = channel.compute_I(t_loc, V, m_old, h_old, D_old)
        t_all.extend(t_old + t_loc[1:])
        I_all.extend(I_loc[1:])
        if D_old is not None:
            D_all.extend(channel.D[1:])
        m_old = channel.m[-1] if m_old is not None else None
        h_old = channel.h[-1] if h_old is not None else None
        D_old = channel.D[-1] if D_old is not None else None
        t_old = t_all[-1]

    if D_old is None:
        ctrl_res = pd.DataFrame({"times": t_all, channel.nest_I: I_all})
    else:
        ctrl_res = pd.DataFrame({"times": t_all, channel.nest_I: I_all, "D": D_all})

    return nest_res, ctrl_res

class Ih(Channel):
    nest_g = "h_g_peak"
    nest_I = "I_h"

    def __init__(self, ht_params):
        self.hp = ht_params

    def tau_m(self, V):
        return 1 / (np.exp(-14.59 - 0.086 * V) + np.exp(-1.87 + 0.0701 * V))

    def m_inf(self, V):
        return 1 / (1 + np.exp((V + 75) / 5.5))

    def compute_I(self, t, V, m0, h0, D0):
        self.m = si.odeint(self.dm, m0, t, args=(V,))
        return -self.hp["h_g_peak"] * self.m * (V - self.hp["h_E_rev"])
    

ih = Ih(nest.GetDefaults("stdp_nestml__with_hill_tononi_nestml"))
nr, cr = voltage_clamp(ih, [(500, -65.0), (500, -80.0), (500, -100.0), (500, -90.0), (500, -55.0)])

# %% [markdown]
# # nest.ResetKernel()
# nest.Install("HT_target/nestml_module")
# nest.set_verbosity("M_ERROR")
#
# ih = Ih(nest.GetDefaults("hill_tononi_nestml__with_stdp_nestml"))
# nr, cr = voltage_clamp(ih, [(500, -65.0), (500, -80.0), (500, -100.0), (500, -90.0), (500, -55.0)])

# %%
import nest
import numpy as np
import matplotlib.pyplot as plt

# Reset e installazione del modulo
nest.ResetKernel()
nest.Install("HT2_target/nestml_module")
nest.set_verbosity("M_ERROR")

# Parametri di simulazione
delta_t = 30  # ms
duration = 10000  # ms
frequency = 1  # Hz

# Creazione dei neuroni
pre_neuron = nest.Create("hill_tononi_nestml__with_stdp_nestml", 1)
post_neuron = nest.Create("hill_tononi_nestml__with_stdp_nestml", 1)

# Configurazione delle sinapsi STDP
wr = nest.Create("weight_recorder")
nest.SetDefaults("stdp_nestml__with_hill_tononi_nestml", {"weight_recorder": wr[0]})

# Definizione del generatore di spike
spike_times = np.array([1500.0, 2000, 2500, 3000])  # Spike a tempi specifici
spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

# Ottieni i tipi di recettori
receptor_types = nest.GetStatus(post_neuron, "receptor_types")[0]
print("Receptor Types:", receptor_types)

# Connessione delle sinapsi eccitatorie e inibitorie al neurone post-sinaptico
synapses = [
    {"receptor_type": receptor_types["AMPA"], "weight": 30.0},
    {"receptor_type": receptor_types["GABA_A"], "weight": 5.0},
    {"receptor_type": receptor_types["GABA_B"], "weight": 10.0},
    {"receptor_type": receptor_types["NMDA"], "weight": 30.0}
]

for syn in synapses:
    nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={
        "synapse_model": "stdp_nestml__with_hill_tononi_nestml",
        "receptor_type": syn["receptor_type"],
        "weight": syn["weight"]
    })

# Definizione del delta temporale
if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t
else:
    delta_pre = -1 * delta_t
    delta_post = 0.0

# Connessione del generatore di spike al neurone pre-sinaptico
synapses_pre = [
    {"receptor_type": receptor_types["AMPA"], "weight": 30.0},
    {"receptor_type": receptor_types["GABA_A"], "weight": 5.0},
    {"receptor_type": receptor_types["GABA_B"], "weight": 10.0},
    {"receptor_type": receptor_types["NMDA"], "weight": 30.0}
]

for syn in synapses_pre:
    nest.Connect(spike_generator, pre_neuron, "one_to_one", syn_spec={
        "synapse_model": "static_synapse",
        "weight": syn["weight"],
        "delay": 1.0 + delta_pre,
        "receptor_type": syn["receptor_type"]
    })

# Connessione del generatore di spike al neurone post-sinaptico
synapses_post = [
    {"receptor_type": receptor_types["AMPA"], "weight": 30.0},
    {"receptor_type": receptor_types["GABA_A"], "weight": 5.0},
    {"receptor_type": receptor_types["GABA_B"], "weight": 10.0},
    {"receptor_type": receptor_types["NMDA"], "weight": 30.0}
]

for syn in synapses_post:
    nest.Connect(spike_generator, post_neuron, "one_to_one", syn_spec={
        "synapse_model": "static_synapse",
        "weight": syn["weight"],
        "delay": 1.0 + delta_post,
        "receptor_type": syn["receptor_type"]
    })

# Creazione dei registratori di spike
sd = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd, "one_to_one")
nest.Connect(post_neuron, sd, "one_to_one")

# Creazione e connessione dei multimetri per le correnti I_NaP e I_KNa
I_Na_rec = nest.Create("multimeter", {"record_from": ["I_NaP"]})
I_K_rec = nest.Create("multimeter", {"record_from": ["I_KNa"]})
nest.Connect(I_Na_rec, post_neuron, "one_to_one")
nest.Connect(I_K_rec, post_neuron, "one_to_one")

# Creazione e connessione dei voltmetri
vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
nest.Connect(vm_pre, pre_neuron, "one_to_one")
nest.Connect(vm_post, post_neuron, "one_to_one")

# Simulazione della rete neurale
nest.Simulate(duration)

# Estrazione degli eventi di spike
spikes = nest.GetStatus(sd, "events")[0]
print("Spike Events:", spikes)

# Estrazione dei dati registrati dai multimetri
I_NaP_events = nest.GetStatus(I_Na_rec, "events")[0]
I_KNa_events = nest.GetStatus(I_K_rec, "events")[0]

# Estrazione dei tempi e dei valori delle correnti
times_I_NaP = I_NaP_events["times"]
values_I_NaP = I_NaP_events["I_NaP"]

times_I_KNa = I_KNa_events["times"]
values_I_KNa = I_KNa_events["I_KNa"]

# Estrazione dei dati dei voltmetri
V_m_pre = nest.GetStatus(vm_pre, "events")[0]
V_m_post = nest.GetStatus(vm_post, "events")[0]

times_vm_pre = V_m_pre["times"]
V_m_pre_values = V_m_pre["V_m"]

times_vm_post = V_m_post["times"]
V_m_post_values = V_m_post["V_m"]

# Plot dei risultati
fig, ax = plt.subplots(5, 1, figsize=(18, 20), sharex=True)

# Potenziale di membrana del neurone pre-sinaptico
ax[0].plot(times_vm_pre, V_m_pre_values, color="b", label="Pre-synaptic Vm")
ax[0].set_title("Potenziale di Membrana Pre-sinaptico")
ax[0].set_ylabel("Vm [mV]")
ax[0].legend()
ax[0].grid(True)

# Potenziale di membrana del neurone post-sinaptico
ax[1].plot(times_vm_post, V_m_post_values, color="orange", label="Post-synaptic Vm")
ax[1].set_title("Potenziale di Membrana Post-sinaptico")
ax[1].set_ylabel("Vm [mV]")
ax[1].legend()
ax[1].grid(True)

# Rasterplot degli spike
ax[2].set_title("Rasterplot")
# Neurone pre-sinaptico (sender=1)
pre_spike_times = spikes['times'][spikes['senders'] == pre_neuron[0]]
ax[2].plot(pre_spike_times, np.ones_like(pre_spike_times), 'b', markersize=10, label="Pre-synaptic spikes")
# Neurone post-sinaptico (sender=2)
post_spike_times = spikes['times'][spikes['senders'] == post_neuron[0]]
ax[2].plot(post_spike_times, np.zeros_like(post_spike_times), 'orange', markersize=10, label="Post-synaptic spikes")
ax[2].legend()
ax[2].set_ylabel("Neurons")
ax[2].set_yticks([0, 1])
ax[2].set_yticklabels(["Post", "Pre"])
ax[2].grid(True)

# STDP (weight recorder)
ax[3].plot(wr.events["times"], wr.events["weights"], color='r')
ax[3].set_title("STDP (Weight Changes)")
ax[3].set_ylabel("Weight [nS]")
ax[3].grid(True)

# Corrente I_NaP
ax[4].plot(times_I_NaP, values_I_NaP, color="b", label="I_NaP")
ax[4].set_title("Corrente I_NaP Registrata")
ax[4].set_ylabel("I_NaP [pA]")
ax[4].set_xlabel("Tempo [ms]")
ax[4].legend()
ax[4].grid(True)

# Aggiunta della corrente I_KNa in un ulteriore sottografico (opzionale)
# Se desideri aggiungere I_KNa, modifica la griglia e aggiungi un nuovo plot

# Ottimizzazione del layout
plt.tight_layout()
plt.show()

# %%
#os.environ['LD_LIBRARY_PATH'] = '/tmp/nestml_target:' + os.environ.get('LD_LIBRARY_PATH', '')
nest.ResetKernel()
nest.Install("HT2_target/nestml_module")
nest.set_verbosity("M_ERROR")

delta_t = 30  # ms
duration = 10000 # ms
frequency = 0.000005  # HzNESTCodeGeneratorUtils.generate_code_for()


pre_neuron = nest.Create("hill_tononi_nestml__with_stdp_nestml", 1)
post_neuron = nest.Create("hill_tononi_nestml__with_stdp_nestml", 1)


wr = nest.Create("weight_recorder")
#nest.SetDefaults("static_synapse", {"weight_recorder": wr[0]})
nest.SetDefaults("stdp_nestml__with_hill_tononi_nestml", {"weight_recorder": wr[0]})

interval = 1000.0 / frequency
spike_times = np.arange(interval, duration, interval)
#spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})
#params={"spike_times": np.array([10.0])}
spike_generator = nest.Create("spike_generator", {"spike_times": np.array([60.0])})


receptor_types = nest.GetStatus(post_neuron, "receptor_types")[0]
print(receptor_types)

#nest.Connect(pre_neuron, post_neuron, "one_to_one", "static_synapse")
#nest.Connect(pre_neuron, post_neuron, "one_to_one", "stdp_nestml__with_hill_tononi_nestml")

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "stdp_nestml__with_hill_tononi_nestml",
                                                              "receptor_type" : receptor_types["AMPA"],
                                                               "weight": 25.0})

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "stdp_nestml__with_hill_tononi_nestml",
                                                              "receptor_type" : receptor_types["GABA_A"],
                                                               "weight": 10.0})

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "stdp_nestml__with_hill_tononi_nestml",
                                                              "receptor_type" : receptor_types["GABA_B"],
                                                               "weight": 1.0})

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec={"synapse_model": "stdp_nestml__with_hill_tononi_nestml",
                                                              "receptor_type" : receptor_types["NMDA"],
                                                               "weight": 20.0})
             
if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t

else:
    delta_pre = -1 * delta_t
    delta_post = 0.0
             
###spike generator per il neurone pre

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 25.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["AMPA"]})

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 10.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["GABA_A"]})

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 1.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["GABA_B"]})

nest.Connect(spike_generator, pre_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 25.0,
                                                          "delay": 1.0 + delta_pre,
                                                          "receptor_type" : receptor_types["NMDA"]})

###spike generator per il neurone post

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 25.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["AMPA"]})

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 10.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["GABA_A"]})

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 1.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["GABA_B"]})

nest.Connect(spike_generator, post_neuron, "one_to_one", {"synapse_model": "static_synapse",
                                                          "weight": 25.0,
                                                          "delay": 1.0 + delta_post,
                                                          "receptor_type" : receptor_types["NMDA"]})
#questa roba funziona!


sd = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd)
nest.Connect(post_neuron, sd)

vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
nest.Connect(vm_pre, pre_neuron)
nest.Connect(vm_post, post_neuron)

nest.Simulate(duration)
spikes = sd.get(['events'][0])

print(sd.events)
fig, ax = plt.subplots(1, 2, figsize = (18,7))

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[0].set_title("First Spike")
ax[0].set_ylabel("Vm [mV]")
ax[0].set_xlim([0,1000])
ax[0].set_xlabel("Time [ms]")
ax[0].legend()

ax[1].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[1].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[1].set_title("Last Spike")
ax[1].set_ylabel("Vm [mV]")
ax[1].set_xlim([0, 10000])
ax[1].set_xlabel("Time [ms]")
ax[1].legend()

fig.tight_layout()

# %%
######prova con i codici della documentazione (nada)

import sys
import math
import numpy as np
import pandas as pd
import scipy.optimize as so
import scipy.integrate as si
import matplotlib.pyplot as plt
import nest

# %matplotlib inline
plt.rcParams["figure.figsize"] = (12, 3)

# %%
nest.ResetKernel()
nest.Install("HT2_target/nestml_module")

class Channel:
    """
    Base class for channel models in Python.
    """

    def tau_m(self, V):
        raise NotImplementedError()

    def tau_h(self, V):
        raise NotImplementedError()

    def m_inf(self, V):
        raise NotImplementedError()

    def h_inf(self, V):
        raise NotImplementedError()

    def D_inf(self, V):
        raise NotImplementedError()

    def dh(self, h, t, V):
        return (self.h_inf(V) - h) / self.tau_h(V)

    def dm(self, m, t, V):
        return (self.m_inf(V) - m) / self.tau_m(V)

# %%
nest.ResetKernel()
nest.Install("HT2_target/nestml_module")

class INaP(Channel):
    nest_g = "NaP_g_peak"
    nest_I = "I_NaP"

    def __init__(self, ht_params):
        self.hp = ht_params

    def m_inf(self, V):
        return 1 / (1 + np.exp(-(V + 55.7) / 7.7))

    def compute_I(self, t, V, m0, h0, D0):
        return self.I_V_curve(V * np.ones_like(t))

    def I_V_curve(self, V):
        self.m = self.m_inf(V)
        return -self.hp["NaP_g_peak"] * self.m**3 * (V - self.hp["E_rev_NaP"])

# %%
def voltage_clamp(channel, DT_V_seq, nest_dt=0.1):
    "Run voltage clamp with voltage V through intervals DT."

    # NEST part
    nest_g_0 = {"g_peak_h": 0.0, "g_peak_T": 0.0, "g_peak_NaP": 0.0, "g_peak_KNa": 0.0}
    nest_g_0[channel.nest_g] = 1.0

    nest.ResetKernel()
    nest.resolution = nest_dt
    nrn = nest.Create("ht_neuron", params=nest_g_0)
    mm = nest.Create("multimeter", params={"record_from": ["V_m", "theta", channel.nest_I], "interval": nest_dt})
    nest.Connect(mm, nrn)

    # ensure we start from equilibrated state
    nrn.set(V_m=DT_V_seq[0][1], equilibrate=True, voltage_clamp=True)
    for DT, V in DT_V_seq:
        nrn.set(V_m=V, voltage_clamp=True)
        nest.Simulate(DT)
    t_end = nest.biological_time

    # simulate a little more so we get all data up to t_end to multimeter
    nest.Simulate(2 * nest.min_delay)

    tmp = pd.DataFrame(mm.events)
    nest_res = tmp[tmp.times <= t_end]

    # Control part
    t_old = 0.0
    try:
        m_old = channel.m_inf(DT_V_seq[0][1])
    except NotImplementedError:
        m_old = None
    try:
        h_old = channel.h_inf(DT_V_seq[0][1])
    except NotImplementedError:
        h_old = None
    try:
        D_old = channel.D_inf(DT_V_seq[0][1])
    except NotImplementedError:
        D_old = None

    t_all, I_all = [], []
    if D_old is not None:
        D_all = []

    for DT, V in DT_V_seq:
        t_loc = np.arange(0.0, DT + 0.1 * nest_dt, nest_dt)
        I_loc = channel.compute_I(t_loc, V, m_old, h_old, D_old)
        t_all.extend(t_old + t_loc[1:])
        I_all.extend(I_loc[1:])
        if D_old is not None:
            D_all.extend(channel.D[1:])
        m_old = channel.m[-1] if m_old is not None else None
        h_old = channel.h[-1] if h_old is not None else None
        D_old = channel.D[-1] if D_old is not None else None
        t_old = t_all[-1]

    if D_old is None:
        ctrl_res = pd.DataFrame({"times": t_all, channel.nest_I: I_all})
    else:
        ctrl_res = pd.DataFrame({"times": t_all, channel.nest_I: I_all, "D": D_all})

    return nest_res, ctrl_res

# %%
iNaP = INaP(nest.GetDefaults("hill_tononi_nestml"))
V = np.arange(-110.0, 30.0, 1.0)
nr, cr = voltage_clamp(iNaP, [(1, v) for v in V], nest_dt=0.1)

# %%
plt.subplot(1, 2, 1)
plt.plot(nr.times, nr.I_NaP, label="NEST")
plt.plot(cr.times, cr.I_NaP, label="Control")
plt.legend(loc="upper left")
plt.xlabel("Time [ms]")
plt.ylabel("I_NaP [mV]")
plt.title("I_NaP current")

plt.subplot(1, 2, 2)
plt.plot(nr.times, (nr.I_NaP - cr.I_NaP))
plt.title("I_NaP error")
plt.xlabel("Time [ms]")
plt.ylabel("Error (NEST-Control)");

# %%
import nest

# Resetta il kernel per evitare conflitti
nest.ResetKernel()

# Elenca tutti i modelli disponibili
neuron_models = nest.Models()
print("Modelli Neurone Disponibili in NEST:")
for model in neuron_models:
    print(f"- {model}")
